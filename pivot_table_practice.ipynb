# %%
import pandas as pd
import numpy as np

pokemon = pd.read_csv('https://raw.githubusercontent.com/lgreski/pokemonData/master/Pokemon.csv', index_col=1)
games = pd.read_csv('clean_games.csv', index_col=0)

# %% [markdown]
# Examine the first few rows of each dataframe. What is the **index** for each?

# %%
# Examine the dataframes here:
games.head()
# Out:
#                      Name  Year  Weight  AvgRating  MinPlayers  MaxPlayers  \
# BGGId
# 1              Die Macher  1986  4.3206    7.61428           3           5
# 2            Dragonmaster  1981  1.9630    6.64537           3           4
# 3                 Samurai  1998  2.4859    7.45601           2           4
# 4          Tal der Könige  1992  2.6667    6.60006           2           4
# 6      Mare Mediterraneum  1989  3.0000    6.55370           2           6
#
#        NumRatings  Kickstarted   Rank  Category
# BGGId
# 1            5354            0    316  Strategy
# 2             562            0   3993  Strategy
# 3           15146            0    224  Strategy
# 4             340            0   5345  Thematic
# 6              81            0  10766  Thematic

# %% [markdown]
# `pokemon` index: "Name"
#
# `games` index: "BGGId"

# %% [markdown]
# Use `pd.pivot_table` to create a dataframe that displays a count of the number of Pokemon of each *primary* type within each generation. Specifically, the rows should represent primary type, the columns should represent the generation, and the values are a count of the number of Pokemon for each type/generation combo.

# %%
# Your code here
pd.pivot_table(pokemon, index = "Type1", values =  "Total", columns="Generation", aggfunc= "count")
# Out:
# Generation     1     2     3     4     5     6     7     8     9
# Type1
# Bug         12.0  10.0  12.0  12.0  18.0   7.0   9.0   4.0   7.0
# Dark         NaN   5.0   4.0   3.0  13.0   6.0   5.0  12.0   8.0
# Dragon       3.0   NaN   7.0   3.0   9.0  10.0   5.0   4.0   8.0
# Electric     9.0   6.0   4.0  12.0   8.0   5.0   7.0  13.0   9.0
# Fairy        2.0   5.0   NaN   1.0   NaN   9.0   1.0   6.0   7.0
# Fighting     7.0   2.0   4.0   2.0   7.0   5.0   4.0  13.0   6.0
# Fire        12.0   8.0   7.0   5.0   9.0  12.0   7.0   8.0   7.0
# Flying       NaN   NaN   NaN   NaN   2.0   2.0   NaN   4.0   2.0
# Ghost        3.0   1.0   4.0   7.0   5.0  12.0   5.0   5.0   5.0
# Grass       12.0   9.0  12.0  14.0  15.0   8.0  13.0  10.0  12.0
# Ground       8.0   3.0   6.0   4.0  10.0   1.0   4.0   6.0   4.0
# Ice          2.0   4.0   7.0   3.0   6.0   3.0   4.0  11.0   3.0
# Normal      22.0  15.0  18.0  17.0  18.0   8.0  13.0   7.0  13.0
# Poison      14.0   1.0   3.0   6.0   2.0   2.0   8.0   5.0   4.0
# Psychic      8.0   7.0  11.0   7.0  14.0  10.0  10.0  13.0   2.0
# Rock         9.0   4.0   8.0   6.0   6.0  11.0  12.0   4.0   7.0
# Steel        NaN   2.0   9.0   3.0   4.0   9.0   4.0   8.0   4.0
# Water       28.0  18.0  25.0  13.0  19.0  11.0  11.0  14.0  11.0
# Bad pipe message: %s [b'.\xe6\x8f-\xa8\x85\xbd\x12)\xbdO\xce/S\xe6\xb9"" \n\x9b\r\x80\xc8\xdb\xc6\xd7\xa8\x83\xae\x98\x7f\x80\xba-\x8bp\xb0\xbcp\xf1\x84L(:r\xc2C\xf8\xbe \x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.', b'\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08']
# Bad pipe message: %s [b'\x08\x08\t\x08\n\x08']
# Bad pipe message: %s [b'\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b"\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 [6\xc1M\t\x05\xb7\xe8\xf9s&L'\x8c\x82\xfb\xecUH\xbe3\xd5"]
# Bad pipe message: %s [b"\xf5^\xf6\xf7\xcf\xea\xd6\xfe`\x87du\x86\x17-\xadK\x97\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t"]
# Bad pipe message: %s [b'7.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00']
# Bad pipe message: %s [b'\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02\x01\x03\x02\x02\x02\x04\x02\x05\x02\x06\x02']
# Bad pipe message: %s [b'1\xc7\t\xa52Qc\x8d\x9c\xbe1\x06uzq<\xe9\x02\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00', b'\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00']
# Bad pipe message: %s [b'\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00']
# Bad pipe message: %s [b'\xf1\xe6\xfa\x18\xc9\xeb\xfb\xb2\xf2Y\xd5\x19\xf0\xe52\x17-"\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x00', b'\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x15\x03\x00\x00\x02\x02']
# Bad pipe message: %s [b'\x8b\xac\xd2\xcb\xda[5\x0c\xae\x97X\xac\xf5\x88\xf6\x1c\x1c;\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00', b'\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0']
# Bad pipe message: %s [b'(\x0ev\xeaw\x1c\xa5\xc0Q\xec#\x13\x01K\xf2[\xe3\xf7\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0', b'\x9d\x00=\x00']
# Bad pipe message: %s [b"\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00"]
# Bad pipe message: %s [b'\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17']

# %% [markdown]
# Use `pd.pivot_table` to create a dataframe that displays the average *number* of reviews for games broken down by category between 2001 and 2021. The categories should be the row labels.

# %%
# Your code here
average = pd.pivot_table(pokemon, index = "Category", values = "NumRatings", columns = "Year" , aggfunc = "mean")
print(average.tail)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Your code here
# ----> 2 average = pd.pivot_table(pokemon, index = "Category", values = "NumRatings", columns = "Year")
#       3 print(average.tail())
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:95, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      92     table = concat(pieces, keys=keys, axis=1)
#      93     return table.__finalize__(data, method="pivot_table")
# ---> 95 table = __internal_pivot_table(
#      96     data,
#      97     values,
#      98     index,
#      99     columns,
#     100     aggfunc,
#     101     fill_value,
#     102     margins,
#     103     dropna,
#     104     margins_name,
#     105     observed,
#     106     sort,
#     107 )
#     108 return table.__finalize__(data, method="pivot_table")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:141, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     139 for i in values:
#     140     if i not in data:
# --> 141         raise KeyError(i)
#     143 to_filter = []
#     144 for x in keys + values:
#
# KeyError: 'NumRatings'

# %%
pokemon.columns
# Out:
# Index(['ID', 'Form', 'Type1', 'Type2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation'],
#       dtype='object')
